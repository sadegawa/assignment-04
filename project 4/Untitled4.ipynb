# %%
# Enter the price of the House you wish to buy
print("Enter the house price")
price =input("500000")

#Enter your Credit Score
print("Enter your Credit Score")
CreditScore =input("500")

# Enter the first name
print("Enter the first name")
first_name = input("Samson")

# Enter the last_name
print("Enter the last name")
last_name = input("Adegawa")

fullnames = first_name + "" + last_name

# Enter the email
print("Enter the email address")
email = input("samsonadegawa@gmail.com")

# Enter the phone number
print("Enter the phone number")
phone = input("2404131378")

# Enter the mailing address
print("Enter the mailing address")
mailing = input("9401 Beechnut Str")

# Enter the City
print("Enter the City")
City = input("Houston")

# Enter the State
print("Enter the State")
State = input("TX")

# Enter the Zipcode
print("Enter the zipcode")
zipcode = input("77036")


#Qualify for loans with the best interest rates
Credit_Score=input("Enter Credit Score")
print("Credit Score: "+ "500")
down_Payment =input("0.0 * 500000")
print("Excellent Credit")
print("Zero Down Payment: ")

#Usually qualify for loans with the best interest rates
CreditScore >= ("740 and 779:")
print("Very Good")
downPayment = float(0.1 * 500000)
print("Downpayment: " + str(50000))

#May face slightly higher loan Interest rates
CreditScore >= "720 and 739:"
print ("Above Average")
downPayment = float(0.3 * 500000)
print("Downpayment: " + str(downPayment))

#May qualify for most loans of higher Interest rates
CreditScore >= "680 and 719:"
print ("Average")
downPayment = float(0.6 * 500000)
print("Downpayment: " + str(downPayment))

#May qualify for most loans at significantly higher Interest rates
CreditScore >= "620 and 679:"
print ("Below Average")
downPayment = float(0.18 * 500000)
print("Downpayment: " + str(downPayment))

# Usually has some credit issues; will probably not 
CreditScore >= "580 and 619:"
print ("Poor Credit Score")
downPayment = float(0.2 * 500000)
print("Downpayment: " + str(downPayment))

#Facing extreme credit issue
CreditScore < "520:"
print ("Poor Credit Score")
downPayment = float(0.25 * 500000)
print("Downpayment: " + str(downPayment))
"else:"
print("invalid output")

print("First name : " + "Samson")
print("Physical address: " + "9401 Beechnut Str")
print("City : " + "Houston")
print("State : " + "TX")
print("Zipcode : " + "77036")
# Out:
# Enter the house price
# 500000
# Enter your Credit Score
# 500
# Enter the first name
# Samson
# Enter the last name
# Adegawa
# Enter the email address
# samsonadegawa@gmail.com
# Enter the phone number
# 2404131378
# Enter the mailing address
# 9401 Beechnut Str
# Enter the City
# Houston
# Enter the State
# TX
# Enter the zipcode
# 77036
# Enter Credit Score
# Credit Score: 500
# 0.0 * 500000
# Excellent Credit
# Zero Down Payment:
# Very Good
# Downpayment: 50000
# Above Average
# Downpayment: 150000.0
# Average
# Downpayment: 300000.0
# Below Average
# Downpayment: 90000.0
# Poor Credit Score
# Downpayment: 100000.0
# Poor Credit Score
# Downpayment: 125000.0
# invalid output
# First name : Samson
# Physical address: 9401 Beechnut Str
# City : Houston
# State : TX
# Zipcode : 77036
